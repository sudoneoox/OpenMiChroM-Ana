# %%
from AnalysisTools import Ana
import numpy as np


        
analysis = Ana(base_folder="test")
analysis.add_dataset(label="chr11", folder="chr11", num_replicas=1)
analysis.add_dataset(label="chr10", folder="chr10", num_replicas=1)

# Process trajectories
analysis.process_trajectories(label="chr10", filename="traj_chr10_0.cndb")
analysis.process_trajectories(label="chr11", filename="traj_chr11_0.cndb")

data1 = analysis.perform_pca("chr10", n_components=2)
data2 = analysis.perform_pca("chr11", n_components=2)

# combined_data = np.vstack([data1, data2])
# labels, centers = analysis.cluster_data(combined_data, n_clusters=5)

# Perform cluster analysis
# analysis.plot_clusters(combined_data, labels, title="Clustering of Chromosome 19 from Different Cell Lines")
# Out:
# Processing file: test/chr10/iteration_1/traj_chr10_0.cndb
# Trajectory for chr10 has shape (1, 2712, 3)
# Processing file: test/chr11/iteration_1/traj_chr11_0.cndb
# Trajectory for chr11 has shape (1, 2703, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 14
#      11 analysis.process_trajectories(label="chr10", filename="traj_chr10_0.cndb")
#      12 analysis.process_trajectories(label="chr11", filename="traj_chr11_0.cndb")
# ---> 14 data1 = analysis.perform_pca("chr10", n_components=2)
#      15 data2 = analysis.perform_pca("chr11", n_components=2)
#      17 # combined_data = np.vstack([data1, data2])
#      18 # labels, centers = analysis.cluster_data(combined_data, n_clusters=5)
#      19
#      20 # Perform cluster analysis
#      21 # analysis.plot_clusters(combined_data, labels, title="Clustering of Chromosome 19 from Different Cell Lines")
#
# ...
