# %%
from Analysis import Ana
import numpy as np


        
analysis = Ana(base_folder="test")
analysis.add_dataset(label="GM12878_chr19", folder="GM12878_19", num_replicas=100)
# analysis.add_dataset(label="IMR90_chr19", folder="IMR90_19", num_replicas=100)

# Process trajectories
analysis.process_trajectories(label="GM12878_chr19", filename="opt_chr19_50K_0_block0.cndb.cndb")
# analysis.process_trajectories(label="IMR90_chr19", filename="opt_chr19_50K_0_block0.cndb.cndb")

data1 = analysis.perform_pca("GM12878_chr19")
# data2 = analysis.perform_pca("IMR90_chr19")

# combined_data = np.vstack([data1, data2])
# labels, centers = analysis.cluster_data(combined_data, n_clusters=5)

# Perform cluster analysis
# analysis.plot_clusters(combined_data, labels, title="Clustering of Chromosome 19 from Different Cell Lines")
# Out:
# File does not exist: test/GM12878_19/iteration_1/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_2/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_3/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_4/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_5/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_6/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_7/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_8/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_9/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_10/opt_chr19_50K_0_block0.cndb.cndb
# File does not exist: test/GM12878_19/iteration_11/opt_chr19_50K_0_block0.cndb.cndb
# ...
