# %%
from AnalysisTools import Ana
import numpy as np


        
analysis = Ana()
analysis.add_dataset(label="GM12878", folder="test/chr19GM12878/lambda46to47")
analysis.add_dataset(label='IMR90', folder='test/chr19IMR90/lambda136to137')
# analysis.add_dataset(label="chr10", folder="chr10", num_replicas=1)

# Process trajectories
analysis.process_trajectories(label="GM12878", filename="traj_12878.cndb", folder_pattern=['iteration_', [1,20]])
analysis.process_trajectories(label="IMR90", filename="traj_12878.cndb", folder_pattern=['iteration_', [1,20]])

# dendogram
analysis.create_dendogram('IMR90', 'GM12878')
analysis.create_euclidian_dist_map(label='IMR90')


# Perform cluster analysis
# analysis.plot_clusters(combined_data, labels, title="Clustering of Chromosome 19 from Different Cell Lines")
# Out:
# Processing file: test/chr19GM12878/lambda46to47/iteration_1/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_2/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_3/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_4/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_5/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_6/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_7/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_8/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_9/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_10/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_11/traj_12878.cndb
# Processing file: test/chr19GM12878/lambda46to47/iteration_12/traj_12878.cndb
# ...
